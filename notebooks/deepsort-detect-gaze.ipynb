# %%
# !python --version
# Out:
# Python 3.12.4

# %%
import ultralytics
import torch

# %%
import cv2
import time
import torch
from ultralytics import YOLO
import numpy as np
from deep_sort.utils.parser import get_config
from deep_sort.deep_sort import DeepSort
from deep_sort.sort.tracker import Tracker
from queue import Queue
from threading import Thread
import json

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

device
# Out:
# device(type='cuda', index=0)

# %%
class_names = ['person', 'bicycle', 'car', 'motorcycle',
               'airplane', 'bus', 'train', 'truck', 'boat',
               'traffic light', 'fire hydrant', 'stop sign',
               'parking meter', 'bench', 'bird', 'cat', 'dog',
               'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra',
               'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard',
               'sports ball', 'kite', 'baseball bat', 'baseball glove',
               'skateboard', 'surfboard', 'tennis racket', 'bottle',
               'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
               'banana', 'apple', 'sandwich', 'orange', 'broccoli',
               'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
               'couch', 'potted plant', 'bed', 'dining table', 'toilet',
         'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
               'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book',
               'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
               'toothbrush']

# %%
MAX_QUEUE_SIZE = 30
SLEEP_TIME = 0.01

# %%
YOLO_MODEL_PATH = "models/yolo/yolov8n.pt"
YOLO_CONFIDENCE_THRESHOLD = 0.5
TARGET_CLASSES = [0, 2, 7, 5, 3]  # person, car, truck, bus, motorcycle

# %%
DEEP_SORT_MODEL_PATH = "deep_sort/deep/checkpoint/ckpt.t7"
DEEP_SORT_MAX_AGE = 20

# %%
INPUT_VIDEO_PATH = "data/videos/Rec16-1_trimmed.mp4"
INPUT_TIMESTAMP_PATH = "output/timestamps/Rec16-1_trimmed.txt"
OUTPUT_PATH = "output/videos/Rec16-1_trimmed_deepsort2.mp4"
OUTPUT_JSON_PATH = "output/json/Rec16-1_trimmed_deepsort2.json"

# %% [markdown]
# # TIMESTAMPS

# %%
def load_timestamps(file_path):
    with open(file_path, 'r') as f:
        return [line.strip() for line in f]

# %% [markdown]
# # GAZE

# %%
def get_circle_BB(whole_frame):
    x_circle = 0.0
    y_circle = 0.0
    r = 0.0

    # Convert to grayscale.
    gray = cv2.cvtColor(whole_frame, cv2.COLOR_BGR2GRAY)

    # Blur using 3 * 3 kernel.
    gray_blurred = cv2.blur(gray, (3, 3))

    # Apply Hough transform on the blurred image.
    detected_circles = cv2.HoughCircles(gray_blurred,
                    cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
                param2 = 30, minRadius = 18, maxRadius = 19)

    # Draw circles that are detected.
    if detected_circles is not None:
        # Convert the circle parameters a, b and r to integers.
        detected_circles = np.uint16(np.around(detected_circles))
        first_circle = detected_circles[0, :][0]
        x_circle, y_circle, r = map(float, first_circle)  # Convert to float

    return x_circle, y_circle, r

# %% [markdown]
# # DEEPSORT

# %%
def read_frames(cap, frame_queue, max_queue_size):
    with torch.no_grad():  # Disable gradient calculation for inference
        while True:
            if frame_queue.qsize() < max_queue_size:
                ret, frame = cap.read()
                if not ret:
                    break
                frame_queue.put(frame)
            else:
                time.sleep(SLEEP_TIME)  # Sleep briefly to prevent busy-waiting
    frame_queue.put(None)  # Signal end of video

# %%
def process_frames(frame_queue, result_queue, model):
    while True:
        frame = frame_queue.get()
        if frame is None:
            break
        
        og_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = model(og_frame, device=0, classes=TARGET_CLASSES, conf=YOLO_CONFIDENCE_THRESHOLD)
        
        # Get gaze coordinates
        x_circle, y_circle, r = get_circle_BB(og_frame)
        
        result_queue.put((og_frame, results, x_circle, y_circle, r))
    result_queue.put(None)

# %%
def track_and_visualize(result_queue, output_queue, tracker, class_names, timestamps):
    unique_track_ids = set()
    frame_index = 0
    results_dict = {}
    
    while True:
        item = result_queue.get()
        if item is None:
            break
        
        og_frame, results, x_circle, y_circle, r = item
        
        timestamp = timestamps[frame_index] if frame_index < len(timestamps) else f"frame_{frame_index}"
        frame_results = []
        gaze_target = None
        
        if len(results) == 0:
            # No detections in this frame
            results_dict[timestamp] = {
                "detections": frame_results,
                "gaze": {
                    "coordinates": [float(x_circle), float(y_circle)],
                    "radius": float(r),
                    "target": gaze_target
                }
            }
            output_queue.put(og_frame)
            frame_index += 1
            continue
        
        result = results[0]  # Assuming single image input
        boxes = result.boxes
        cls = boxes.cls.tolist()
        xyxy = boxes.xyxy
        conf = boxes.conf
        xywh = boxes.xywh
        
        if len(cls) == 0:
            # No classes detected in this frame
            results_dict[timestamp] = {
                "detections": frame_results,
                "gaze": {
                    "coordinates": [float(x_circle), float(y_circle)],
                    "radius": float(r),
                    "target": gaze_target
                }
            }
            output_queue.put(og_frame)
            frame_index += 1
            continue
        
        pred_cls = np.array(cls)
        conf = conf.detach().cpu().numpy()
        xyxy = xyxy.detach().cpu().numpy()
        bboxes_xywh = xywh.cpu().numpy()
        
        tracks = tracker.update(bboxes_xywh, conf, og_frame)
        for track in tracker.tracker.tracks:
            track_id = track.track_id
            x1, y1, x2, y2 = track.to_tlbr()
            w = x2 - x1
            h = y2 - y1
            
            color_id = track_id % 3
            color = [(0, 0, 255), (255, 0, 0), (0, 255, 0)][color_id]
            
            cv2.rectangle(og_frame, (int(x1), int(y1)), (int(x1 + w), int(y1 + h)), color, 2)
            
            # Safely get class name
            class_index = int(cls[track_id % len(cls)]) if cls else 0
            class_name = class_names[class_index] if class_index < len(class_names) else "Unknown"
            
            cv2.putText(og_frame, f"{class_name}-{track_id}", (int(x1) + 10, int(y1) - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            
            unique_track_ids.add(track_id)
            
            # Store detection and tracking information
            detection_info = {
                "track_id": int(track_id),
                "class": class_name,
                "bbox": [float(x1), float(y1), float(x2), float(y2)],
                "confidence": float(conf[track_id % len(conf)])  # Safely get confidence
            }
            frame_results.append(detection_info)
            
            # Check if gaze is inside this bounding box
            if x1 <= x_circle <= x2 and y1 <= y_circle <= y2:
                gaze_target = detection_info
        
        # Draw gaze circle
        cv2.circle(og_frame, (int(x_circle), int(y_circle)), int(r), (0, 255, 255), 2)
        
        results_dict[timestamp] = {
            "detections": frame_results,
            "gaze": {
                "coordinates": [float(x_circle), float(y_circle)],
                "target": gaze_target
            }
        }
        output_queue.put(og_frame)
        frame_index += 1
    
    # Save results to JSON file
    with open(OUTPUT_JSON_PATH, 'w') as f:
        json.dump(results_dict, f, indent=2)
    
    output_queue.put(None)

# %%
def write_video(output_queue, out):
    while True:
        frame = output_queue.get()
        if frame is None:
            break
        out.write(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))

# %%
def process_video(input_path, output_path, timestamps_path, yolo_model_path=YOLO_MODEL_PATH):
    yolo_model = YOLO(yolo_model_path)
    tracker = DeepSort(model_path=DEEP_SORT_MODEL_PATH, max_age=DEEP_SORT_MAX_AGE)
    timestamps = load_timestamps(timestamps_path)

    cap = cv2.VideoCapture(input_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    assert len(timestamps) == total_frames, "Number of timestamps must match number of frames in video"

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_queue = Queue(maxsize=MAX_QUEUE_SIZE)
    result_queue = Queue(maxsize=MAX_QUEUE_SIZE)
    output_queue = Queue(maxsize=MAX_QUEUE_SIZE)
    
    read_thread = Thread(target=read_frames, args=(cap, frame_queue, MAX_QUEUE_SIZE))
    process_thread = Thread(target=process_frames, args=(frame_queue, result_queue, yolo_model))
    track_thread = Thread(target=track_and_visualize, args=(result_queue, output_queue, tracker, class_names, timestamps))
    write_thread = Thread(target=write_video, args=(output_queue, out))
    
    read_thread.start()
    process_thread.start()
    track_thread.start()
    write_thread.start()

    read_thread.join()
    process_thread.join()
    track_thread.join()
    write_thread.join()

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
process_video(INPUT_VIDEO_PATH, OUTPUT_PATH, INPUT_TIMESTAMP_PATH)
# Out:
# 0: 352x640 (no detections), 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 14.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 91.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.0ms
# Speed: 17.8ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.3ms
# Speed: 7.3ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 17.2ms
# Speed: 3.5ms preprocess, 17.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.6ms
# Speed: 2.7ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 16.4ms
# Speed: 3.6ms preprocess, 16.4ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 8.9ms
# Speed: 4.8ms preprocess, 8.9ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 16.7ms
# Speed: 3.2ms preprocess, 16.7ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.9ms
# Speed: 5.2ms preprocess, 10.9ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.0ms
# Speed: 5.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.1ms
# Speed: 3.5ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.6ms
# Speed: 3.9ms preprocess, 9.6ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.2ms
# Speed: 2.5ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 14.7ms
# Speed: 2.7ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 8.3ms
# Speed: 2.8ms preprocess, 8.3ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 7.8ms
# Speed: 4.7ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.8ms
# Speed: 4.4ms preprocess, 9.8ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.2ms
# Speed: 4.0ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.3ms
# Speed: 3.2ms preprocess, 9.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 12.3ms
# Speed: 3.9ms preprocess, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.4ms
# Speed: 2.4ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 9.9ms
# Speed: 3.2ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.1ms
# Speed: 3.3ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 8.4ms
# Speed: 4.9ms preprocess, 8.4ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 6.5ms
# Speed: 4.0ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.0ms
# Speed: 3.8ms preprocess, 9.0ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 11.8ms
# Speed: 2.6ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.4ms
# Speed: 2.4ms preprocess, 13.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.4ms
# Speed: 3.3ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.8ms
# Speed: 2.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.7ms
# Speed: 2.5ms preprocess, 11.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.4ms
# Speed: 3.7ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.7ms
# Speed: 4.4ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 10.9ms
# Speed: 5.0ms preprocess, 10.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 3.3ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 5.9ms
# Speed: 1.7ms preprocess, 5.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 7.0ms
# Speed: 4.7ms preprocess, 7.0ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.4ms
# Speed: 2.3ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.2ms
# Speed: 2.8ms preprocess, 8.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.7ms
# Speed: 3.3ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.9ms
# Speed: 2.7ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 7.9ms
# Speed: 3.8ms preprocess, 7.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.9ms
# Speed: 5.0ms preprocess, 11.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 16.2ms
# Speed: 3.4ms preprocess, 16.2ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.2ms
# Speed: 4.3ms preprocess, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.2ms
# Speed: 4.8ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 6.3ms
# Speed: 2.3ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 14.1ms
# Speed: 2.8ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 37.4ms
# Speed: 3.4ms preprocess, 37.4ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle,