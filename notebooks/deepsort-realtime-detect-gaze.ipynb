# %%
# !python --version
# Out:
# Python 3.12.4

# %%
import ultralytics
import torch

# %%
import cv2
import time
import torch
from ultralytics import YOLO
import numpy as np
from deep_sort_realtime.deepsort_tracker import DeepSort
from queue import Queue
from threading import Thread
import json

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

device
# Out:
# device(type='cuda', index=0)

# %%
class_names = ['person', 'bicycle', 'car', 'motorcycle',
               'airplane', 'bus', 'train', 'truck', 'boat',
               'traffic light', 'fire hydrant', 'stop sign',
               'parking meter', 'bench', 'bird', 'cat', 'dog',
               'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra',
               'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard',
               'sports ball', 'kite', 'baseball bat', 'baseball glove',
               'skateboard', 'surfboard', 'tennis racket', 'bottle',
               'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
               'banana', 'apple', 'sandwich', 'orange', 'broccoli',
               'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair',
               'couch', 'potted plant', 'bed', 'dining table', 'toilet',
         'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
               'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book',
               'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
               'toothbrush']

# %%
MAX_QUEUE_SIZE = 30
SLEEP_TIME = 0.01

# %%
YOLO_MODEL_PATH = "models/yolo/yolov8n.pt"
YOLO_CONFIDENCE_THRESHOLD = 0.5
TARGET_CLASSES = [0, 2, 7, 5, 3]  # person, car, truck, bus, motorcycle

# %%
DEEP_SORT_MODEL_PATH = "deep_sort/deep/checkpoint/ckpt.t7"
DEEP_SORT_MAX_AGE = 5

# %%
INPUT_VIDEO_PATH = "data/videos/Rec16-1_trimmed.mp4"
INPUT_TIMESTAMP_PATH = "output/timestamps/Rec16-1_trimmed.txt"
OUTPUT_PATH = "output/videos/Rec16-1_trimmed_deepsort4.mp4"
OUTPUT_JSON_PATH = "output/json/Rec16-1_trimmed_deepsort4.json"

# %% [markdown]
# # TIMESTAMPS

# %%
def load_timestamps(file_path):
    with open(file_path, 'r') as f:
        return [line.strip() for line in f]

# %% [markdown]
# # GAZE

# %%
def get_circle_BB(whole_frame):
    x_circle = 0.0
    y_circle = 0.0
    r = 0.0

    # Convert to grayscale.
    gray = cv2.cvtColor(whole_frame, cv2.COLOR_BGR2GRAY)

    # Blur using 3 * 3 kernel.
    gray_blurred = cv2.blur(gray, (3, 3))

    # Apply Hough transform on the blurred image.
    detected_circles = cv2.HoughCircles(gray_blurred,
                    cv2.HOUGH_GRADIENT, 1, 20, param1 = 50,
                param2 = 30, minRadius = 18, maxRadius = 19)

    # Draw circles that are detected.
    if detected_circles is not None:
        # Convert the circle parameters a, b and r to integers.
        detected_circles = np.uint16(np.around(detected_circles))
        first_circle = detected_circles[0, :][0]
        x_circle, y_circle, r = map(float, first_circle)  # Convert to float

    return x_circle, y_circle, r

# %% [markdown]
# # DEEPSORT

# %%
def read_frames(cap, frame_queue, max_queue_size):
    with torch.no_grad():  # Disable gradient calculation for inference
        while True:
            if frame_queue.qsize() < max_queue_size:
                ret, frame = cap.read()
                if not ret:
                    break
                frame_queue.put(frame)
            else:
                time.sleep(SLEEP_TIME)  # Sleep briefly to prevent busy-waiting
    frame_queue.put(None)  # Signal end of video

# %%
# def process_frames(frame_queue, result_queue, model):
#     while True:
#         frame = frame_queue.get()
#         if frame is None:
#             break
        
#         og_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         results = model(og_frame, device=0, classes=TARGET_CLASSES, conf=YOLO_CONFIDENCE_THRESHOLD)
        
#         # Get gaze coordinates
#         x_circle, y_circle, r = get_circle_BB(og_frame)
        
#         result_queue.put((og_frame, results, x_circle, y_circle, r))
#     result_queue.put(None)
def process_frames(frame_queue, result_queue, model):
    while True:
        frame = frame_queue.get()
        if frame is None:
            break
        
        try:
            results = model(frame, device=0, classes=TARGET_CLASSES, conf=YOLO_CONFIDENCE_THRESHOLD)
            result = results[0] if results else None
        except Exception as e:
            print(f"Error processing frame with YOLO: {e}")
            result = None
        
        # Get gaze coordinates
        try:
            x_circle, y_circle, r = get_circle_BB(frame)
        except Exception as e:
            print(f"Error getting gaze coordinates: {e}")
            x_circle, y_circle, r = 0, 0, 0
        
        result_queue.put((frame, result, x_circle, y_circle, r))
    result_queue.put(None)

# %%
def track_and_visualize(result_queue, output_queue, tracker, class_names, timestamps):
    frame_index = 0
    results_dict = {}
    
    while True:
        item = result_queue.get()
        if item is None:
            break
        
        frame, results, x_circle, y_circle, r = item
        
        timestamp = timestamps[frame_index] if frame_index < len(timestamps) else f"frame_{frame_index}"
        frame_results = []
        gaze_target = None
        
        # Process YOLO results into the format expected by DeepSort
        detections = []
        if results and len(results) > 0:
            for box in results[0].boxes:
                x1, y1, x2, y2 = box.xyxy[0].tolist()
                conf = box.conf.item()
                cls = int(box.cls.item())
                w = x2 - x1
                h = y2 - y1
                detections.append(([x1, y1, w, h], conf, cls))
        
        # Update tracks
        tracks = tracker.update_tracks(detections, frame=frame)
        
        for track in tracks:
            if not track.is_confirmed():
                continue
            
            track_id = track.track_id
            ltrb = track.to_ltrb()
            x1, y1, x2, y2 = map(int, ltrb)
            
            # Get class name
            class_id = track.get_det_class()
            class_name = class_names[class_id] if class_id < len(class_names) else "Unknown"
            
            # Draw bounding box
            color = [(0, 255, 0), (255, 0, 0), (0, 0, 255)][int(track_id) % 3]
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            
            # Draw label
            label = f"{class_name}-{track_id}"
            cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            
            # Store detection and tracking information
            detection_info = {
                "track_id": int(track_id),
                "class": class_name,
                "bbox": [float(x1), float(y1), float(x2), float(y2)],
                "confidence": float(track.get_det_conf()) if track.get_det_conf() else None
            }
            frame_results.append(detection_info)
            
            # Check if gaze is inside this bounding box
            if x1 <= x_circle <= x2 and y1 <= y_circle <= y2:
                gaze_target = detection_info
        
        # Draw gaze circle
        cv2.circle(frame, (int(x_circle), int(y_circle)), int(r), (0, 255, 255), 2)
        
        results_dict[timestamp] = {
            "detections": frame_results,
            "gaze": {
                "coordinates": [float(x_circle), float(y_circle)],
                "radius": float(r),
                "target": gaze_target
            }
        }
        
        output_queue.put(frame)
        frame_index += 1
    
    # Save results to JSON file
    with open(OUTPUT_JSON_PATH, 'w') as f:
        json.dump(results_dict, f, indent=2)
    
    output_queue.put(None)

# %%
def write_video(output_queue, out):
    while True:
        frame = output_queue.get()
        if frame is None:
            break
        out.write(cv2.cvtColor(frame, cv2.COLOR_RGB2BGR))

# %%
def process_video(input_path, output_path, timestamps_path, yolo_model_path=YOLO_MODEL_PATH):
    yolo_model = YOLO(yolo_model_path)
    tracker = DeepSort(max_age=DEEP_SORT_MAX_AGE, nn_budget=100,
                       nms_max_overlap=1.0,
                       max_cosine_distance=0.3,
                       max_iou_distance=0.7, n_init=3)

    timestamps = load_timestamps(timestamps_path)

    cap = cv2.VideoCapture(input_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_queue = Queue(maxsize=MAX_QUEUE_SIZE)
    result_queue = Queue(maxsize=MAX_QUEUE_SIZE)
    output_queue = Queue(maxsize=MAX_QUEUE_SIZE)
    
    read_thread = Thread(target=read_frames, args=(cap, frame_queue, MAX_QUEUE_SIZE))
    process_thread = Thread(target=process_frames, args=(frame_queue, result_queue, yolo_model))
    track_thread = Thread(target=track_and_visualize, args=(result_queue, output_queue, tracker, class_names, timestamps))
    write_thread = Thread(target=write_video, args=(output_queue, out))
    
    read_thread.start()
    process_thread.start()
    track_thread.start()
    write_thread.start()

    read_thread.join()
    process_thread.join()
    track_thread.join()
    write_thread.join()

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
process_video(INPUT_VIDEO_PATH, OUTPUT_PATH, INPUT_TIMESTAMP_PATH)
# Out:
# 0: 352x640 (no detections), 75.5ms
# Speed: 5.1ms preprocess, 75.5ms inference, 41.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 22.3ms
# Speed: 1.9ms preprocess, 22.3ms inference, 181.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.5ms
# Speed: 4.8ms preprocess, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 14.7ms
# Speed: 2.8ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.1ms
# Speed: 3.4ms preprocess, 13.1ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 14.1ms
# Speed: 2.7ms preprocess, 14.1ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.4ms
# Speed: 3.2ms preprocess, 13.4ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 11.7ms
# Speed: 4.2ms preprocess, 11.7ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 11.4ms
# Speed: 2.3ms preprocess, 11.4ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 15.2ms
# Speed: 4.0ms preprocess, 15.2ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 17.6ms
# Speed: 5.2ms preprocess, 17.6ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 10.6ms
# Speed: 5.8ms preprocess, 10.6ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.7ms
# Speed: 3.3ms preprocess, 11.7ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.4ms
# Speed: 3.2ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 4.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.4ms
# Speed: 3.0ms preprocess, 11.4ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.3ms
# Speed: 3.5ms preprocess, 13.3ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.6ms
# Speed: 4.3ms preprocess, 12.6ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.3ms
# Speed: 4.9ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.3ms
# Speed: 4.8ms preprocess, 13.3ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 14.1ms
# Speed: 5.0ms preprocess, 14.1ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.8ms
# Speed: 9.2ms preprocess, 11.8ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.3ms
# Speed: 3.3ms preprocess, 12.3ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 23.9ms
# Speed: 3.4ms preprocess, 23.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.7ms
# Speed: 4.0ms preprocess, 12.7ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 12.5ms
# Speed: 3.3ms preprocess, 12.5ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.3ms
# Speed: 3.5ms preprocess, 10.3ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.5ms
# Speed: 5.4ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 11.4ms
# Speed: 5.6ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.8ms
# Speed: 4.4ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.4ms
# Speed: 3.1ms preprocess, 13.4ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.2ms
# Speed: 2.8ms preprocess, 13.2ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 14.1ms
# Speed: 4.6ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.2ms
# Speed: 3.3ms preprocess, 11.2ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 10.5ms
# Speed: 2.7ms preprocess, 10.5ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.5ms
# Speed: 2.3ms preprocess, 12.5ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 12.8ms
# Speed: 2.3ms preprocess, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 12.7ms
# Speed: 4.6ms preprocess, 12.7ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.5ms
# Speed: 4.5ms preprocess, 13.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 3.3ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.7ms
# Speed: 3.2ms preprocess, 11.7ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 motorcycles, 11.3ms
# Speed: 2.8ms preprocess, 11.3ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.1ms
# Speed: 6.4ms preprocess, 12.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 8.6ms
# Speed: 3.9ms preprocess, 8.6ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 11.2ms
# Speed: 4.1ms preprocess, 11.2ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.7ms
# Speed: 3.4ms preprocess, 7.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.8ms
# Speed: 2.7ms preprocess, 6.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.0ms
# Speed: 4.7ms preprocess, 13.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 3.9ms preprocess, 7.5ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 3.4ms preprocess, 7.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.2ms
# Speed: 3.1ms preprocess, 7.2ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 3.1ms preprocess, 9.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 12.6ms
# Speed: 2.2ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.8ms
# Speed: 3.4ms preprocess, 9.8ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.5ms
# Speed: 2.7ms preprocess, 12.5ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.6ms
# Speed: 2.9ms preprocess, 11.6ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.5ms
# Speed: 4.7ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.8ms
# Speed: 3.9ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.2ms
# Speed: 3.3ms preprocess, 10.2ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.7ms
# Speed: 3.4ms preprocess, 10.7ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 12.0ms
# Speed: 4.7ms preprocess, 12.0ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.9ms
# Speed: 3.2ms preprocess, 13.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 13.0ms
# Speed: 5.3ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.9ms
# Speed: 2.6ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.8ms
# Speed: 3.8ms preprocess, 9.8ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 12.2ms
# Speed: 5.0ms preprocess, 12.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 17.8ms
# Speed: 4.9ms preprocess, 17.8ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 21.3ms
# Speed: 3.3ms preprocess, 21.3ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 2 motorcycles, 26.9ms
# Speed: 3.7ms preprocess, 26.9ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.8ms
# Speed: 5.0ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 11.9ms
# Speed: 5.7ms preprocess, 11.9ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 11.9ms
# Speed: 3.7ms preprocess, 11.9ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 12.1ms
# Speed: 2.1ms preprocess, 12.1ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 12.9ms
# Speed: 2.7ms preprocess, 12.9ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 11.3ms
# Speed: 3.9ms preprocess, 11.3ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 1 motorcycle, 12.6ms
# Speed: 3.0ms preprocess, 12.6ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 motorcycle, 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 1 motorcycle, 27.9ms
# Speed: 3.2ms preprocess, 27.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 1 motorcycle, 11.6ms
# Speed: 3.3ms preprocess, 11.6ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 1 motorcycle, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 12.1ms
# Speed: 3.4ms preprocess, 12.1ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.1ms
# Speed: 4.1ms preprocess, 9.1ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.8ms
# Speed: 2.8ms preprocess, 10.8ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.4ms
# Speed: 2.9ms preprocess, 13.4ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.6ms
# Speed: 5.8ms preprocess, 13.6ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.5ms
# Speed: 3.9ms preprocess, 11.5ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 motorcycle, 11.4ms
# Speed: 4.9ms preprocess, 11.4ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 12.9ms
# Speed: 3.9ms preprocess, 12.9ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 car, 13.4ms
# Speed: 4.7ms preprocess, 13.4ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 persons, 1 car, 1 motorcycle, 14.1ms
# Speed: 3.6ms preprocess, 14.1ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 persons, 1 motorcycle, 11.3ms
# Speed: 3.7ms preprocess, 11.3ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 12.4ms
# Speed: 2.9ms preprocess, 12.4ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 14.3ms
# Speed: 3.2ms preprocess, 14.3ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 14.0ms
# Speed: 2.6ms preprocess, 14.0ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.5ms
# Speed: 3.8ms preprocess, 13.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.4ms
# Speed: 4.4ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.1ms
# Speed: 4.5ms preprocess, 14.1ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 person, 1 car, 13.4ms
# Speed: 4.1ms preprocess, 13.4ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.9ms
# Speed: 3.6ms preprocess, 10.9ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.3ms
# Speed: 3.3ms preprocess, 10.3ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 15.1ms
# Speed: 3.5ms preprocess, 15.1ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 12.4ms
# Speed: 4.7ms preprocess, 12.4ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 10.8ms
# Speed: 2.7ms preprocess, 10.8ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 12.8ms
# Speed: 3.8ms preprocess, 12.8ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 15.0ms
# Speed: 3.4ms preprocess, 15.0ms inference, 6.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.8ms
# Speed: 4.4ms preprocess, 13.8ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.3ms
# Speed: 3.7ms preprocess, 12.3ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.5ms
# Speed: 2.6ms preprocess, 12.5ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 13.1ms
# Speed: 3.7ms preprocess, 13.1ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 12.8ms
# Speed: 2.0ms preprocess, 12.8ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.7ms
# Speed: 2.3ms preprocess, 10.7ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 10.1ms
# Speed: 2.5ms preprocess, 10.1ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 1 motorcycle, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 1 motorcycle, 11.8ms
# Speed: 2.9ms preprocess, 11.8ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.8ms
# Speed: 2.2ms preprocess, 10.8ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.9ms
# Speed: 3.3ms preprocess, 11.9ms inference, 5.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.8ms
# Speed: 3.8ms preprocess, 11.8ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.5ms
# Speed: 4.7ms preprocess, 12.5ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.8ms
# Speed: 2.4ms preprocess, 10.8ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 5.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.2ms
# Speed: 3.8ms preprocess, 12.2ms inference, 4.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.6ms
# Speed: 2.7ms preprocess, 14.6ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.7ms
# Speed: 2.2ms preprocess, 12.7ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.5ms
# Speed: 2.4ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.9ms
# Speed: 3.5ms preprocess, 9.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.8ms
# Speed: 2.9ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.7ms
# Speed: 3.7ms preprocess, 12.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.0ms
# Speed: 4.0ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.2ms
# Speed: 4.5ms preprocess, 14.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 4.3ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 4.5ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.8ms
# Speed: 3.9ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.2ms
# Speed: 2.8ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 3.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.3ms
# Speed: 3.9ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 3.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.3ms
# Speed: 2.4ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 3.2ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.3ms
# Speed: 3.7ms preprocess, 7.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 3.7ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.2ms
# Speed: 2.8ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.1ms
# Speed: 3.2ms preprocess, 8.1ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 4.1ms preprocess, 7.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.3ms
# Speed: 3.3ms preprocess, 14.3ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.3ms
# Speed: 3.8ms preprocess, 14.3ms inference, 4.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.5ms
# Speed: 6.1ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 31.6ms
# Speed: 4.7ms preprocess, 31.6ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.9ms
# Speed: 2.8ms preprocess, 10.9ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 5.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.3ms
# Speed: 3.5ms preprocess, 13.3ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.9ms
# Speed: 3.4ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.2ms
# Speed: 5.3ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.8ms
# Speed: 4.4ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.7ms
# Speed: 3.0ms preprocess, 9.7ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.1ms
# Speed: 3.2ms preprocess, 12.1ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.3ms
# Speed: 3.1ms preprocess, 11.3ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.3ms
# Speed: 3.3ms preprocess, 11.3ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.4ms
# Speed: 3.8ms preprocess, 10.4ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.0ms
# Speed: 2.6ms preprocess, 12.0ms inference, 4.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 15.3ms
# Speed: 3.9ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.8ms
# Speed: 4.2ms preprocess, 13.8ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.9ms
# Speed: 5.8ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.5ms
# Speed: 3.3ms preprocess, 9.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 10.6ms
# Speed: 3.6ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.4ms
# Speed: 4.1ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 16.0ms
# Speed: 3.4ms preprocess, 16.0ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.5ms
# Speed: 11.2ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.4ms
# Speed: 5.9ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 7.2ms
# Speed: 4.1ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.5ms
# Speed: 2.8ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.0ms
# Speed: 3.5ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.8ms
# Speed: 3.1ms preprocess, 7.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.7ms
# Speed: 3.5ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.2ms
# Speed: 3.2ms preprocess, 6.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 3.4ms preprocess, 8.0ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.8ms
# Speed: 2.6ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.8ms
# Speed: 2.7ms preprocess, 7.8ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 3.3ms preprocess, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.2ms
# Speed: 4.1ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.6ms
# Speed: 3.6ms preprocess, 9.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 8.5ms
# Speed: 3.7ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.4ms
# Speed: 2.6ms preprocess, 11.4ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.2ms
# Speed: 6.1ms preprocess, 11.2ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.7ms
# Speed: 3.3ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.7ms
# Speed: 3.2ms preprocess, 11.7ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.1ms
# Speed: 4.1ms preprocess, 9.1ms inference, 3.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.7ms
# Speed: 3.0ms preprocess, 11.7ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 25.2ms
# Speed: 3.8ms preprocess, 25.2ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 cars, 17.1ms
# Speed: 3.5ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 3 cars, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 9.8ms
# Speed: 3.7ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 12.5ms
# Speed: 3.1ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.4ms
# Speed: 2.7ms preprocess, 12.4ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 11.1ms
# Speed: 3.7ms preprocess, 11.1ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 20.3ms
# Speed: 4.7ms preprocess, 20.3ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 14.0ms
# Speed: 5.1ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 3.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.9ms
# Speed: 4.3ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 bus, 8.1ms
# Speed: 3.4ms preprocess, 8.1ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.4ms
# Speed: 6.8ms preprocess, 11.4ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.6ms
# Speed: 3.7ms preprocess, 11.6ms inference, 3.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.3ms
# Speed: 3.6ms preprocess, 13.3ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.8ms
# Speed: 3.4ms preprocess, 12.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.0ms
# Speed: 3.8ms preprocess, 11.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.6ms
# Speed: 3.5ms preprocess, 11.6ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.1ms
# Speed: 3.4ms preprocess, 12.1ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 12.5ms
# Speed: 2.8ms preprocess, 12.5ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 18.0ms
# Speed: 3.4ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.8ms
# Speed: 4.1ms preprocess, 13.8ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.9ms
# Speed: 3.9ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 5.9ms
# Speed: 3.9ms preprocess, 5.9ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 3.0ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 6.9ms
# Speed: 3.8ms preprocess, 6.9ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 3.3ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 truck, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.8ms
# Speed: 3.6ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 3.2ms preprocess, 7.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.2ms
# Speed: 4.0ms preprocess, 8.2ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.8ms
# Speed: 4.6ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.5ms
# Speed: 4.1ms preprocess, 13.5ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.8ms
# Speed: 3.9ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.8ms
# Speed: 3.3ms preprocess, 11.8ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.5ms
# Speed: 4.6ms preprocess, 10.5ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.9ms
# Speed: 2.2ms preprocess, 11.9ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 10.9ms
# Speed: 2.3ms preprocess, 10.9ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 11.8ms
# Speed: 3.4ms preprocess, 11.8ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 12.2ms
# Speed: 4.6ms preprocess, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 10.5ms
# Speed: 3.7ms preprocess, 10.5ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 2 cars, 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 3.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.2ms
# Speed: 2.7ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.1ms
# Speed: 4.8ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.5ms
# Speed: 2.7ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.3ms
# Speed: 5.2ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.5ms
# Speed: 4.0ms preprocess, 8.5ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.7ms
# Speed: 3.4ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.8ms
# Speed: 4.3ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.1ms
# Speed: 4.2ms preprocess, 8.1ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 3.5ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.2ms
# ...
#
# 0: 352x640 (no detections), 9.5ms
# Speed: 5.5ms preprocess, 9.5ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.5ms
# Speed: 4.4ms preprocess, 12.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 24.7ms
# Speed: 13.9ms preprocess, 24.7ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.5ms
# Speed: 7.7ms preprocess, 13.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 30.2ms
# Speed: 5.0ms preprocess, 30.2ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.2ms
# Speed: 5.6ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.7ms
# Speed: 4.6ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.3ms
# Speed: 4.3ms preprocess, 13.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.7ms
# Speed: 5.0ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 23.0ms
# Speed: 12.6ms preprocess, 23.0ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 20.1ms
# Speed: 5.7ms preprocess, 20.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.7ms
# Speed: 4.7ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.1ms
# Speed: 2.8ms preprocess, 13.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.1ms
# Speed: 3.5ms preprocess, 13.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 25.3ms
# Speed: 4.4ms preprocess, 25.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.7ms
# Speed: 3.4ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.8ms
# Speed: 4.8ms preprocess, 12.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.1ms
# Speed: 6.4ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.7ms
# Speed: 4.3ms preprocess, 9.7ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.5ms
# Speed: 5.2ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.3ms
# Speed: 3.9ms preprocess, 13.3ms inference, 2.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 22.2ms
# Speed: 4.3ms preprocess, 22.2ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 34.6ms
# Speed: 7.4ms preprocess, 34.6ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.7ms
# Speed: 4.5ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 16.3ms
# Speed: 4.7ms preprocess, 16.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.3ms
# Speed: 4.6ms preprocess, 13.3ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.8ms
# Speed: 3.7ms preprocess, 11.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 38.1ms
# Speed: 4.4ms preprocess, 38.1ms inference, 5.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 27.4ms
# Speed: 5.5ms preprocess, 27.4ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.8ms
# Speed: 4.0ms preprocess, 14.8ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 27.5ms
# Speed: 2.7ms preprocess, 27.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.5ms
# Speed: 5.3ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.5ms
# Speed: 4.3ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.3ms
# Speed: 3.2ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 24.0ms
# Speed: 4.3ms preprocess, 24.0ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 9.1ms
# Speed: 7.5ms preprocess, 9.1ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 16.1ms
# Speed: 2.7ms preprocess, 16.1ms inference, 5.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.5ms
# Speed: 4.6ms preprocess, 14.5ms inference, 6.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.4ms
# Speed: 4.3ms preprocess, 13.4ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.8ms
# Speed: 3.6ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.1ms
# Speed: 4.1ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 21.1ms
# Speed: 6.0ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 3.9ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.8ms
# Speed: 3.0ms preprocess, 11.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 2.8ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 26.3ms
# Speed: 4.3ms preprocess, 26.3ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.6ms
# Speed: 5.9ms preprocess, 12.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 22.9ms
# Speed: 4.0ms preprocess, 22.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.1ms
# Speed: 4.4ms preprocess, 14.1ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 13.9ms
# Speed: 6.5ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 12.1ms
# Speed: 2.1ms preprocess, 12.1ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 20.0ms
# Speed: 7.2ms preprocess, 20.0ms inference, 4.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 4.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.7ms
# Speed: 2.7ms preprocess, 14.7ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.2ms
# Speed: 3.8ms preprocess, 14.2ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 14.2ms
# Speed: 3.2ms preprocess, 14.2ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.4ms
# Speed: 5.4ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 26.7ms
# Speed: 4.1ms preprocess, 26.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 13.3ms
# Speed: 5.8ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.0ms
# Speed: 3.9ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.6ms
# Speed: 4.6ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.0ms
# Speed: 5.7ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.3ms
# Speed: 4.1ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.7ms
# Speed: 4.0ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 4.5ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.5ms
# Speed: 3.5ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 18.3ms
# Speed: 3.9ms preprocess, 18.3ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 17.8ms
# Speed: 4.5ms preprocess, 17.8ms inference, 18.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.9ms
# Speed: 3.2ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.1ms
# Speed: 2.9ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 11.4ms
# Speed: 2.3ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 9.3ms
# Speed: 3.9ms preprocess, 9.3ms inference, 3.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 3.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 26.9ms
# Speed: 7.7ms preprocess, 26.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 13.7ms
# Speed: 3.6ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 3.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 14.3ms
# Speed: 2.9ms preprocess, 14.3ms inference, 4.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 18.0ms
# Speed: 11.4ms preprocess, 18.0ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 10.5ms
# Speed: 2.6ms preprocess, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 19.0ms
# Speed: 16.3ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 motorcycle, 14.3ms
# Speed: 3.4ms preprocess, 14.3ms inference, 2.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.9ms
# Speed: 2.7ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.9ms
# Speed: 3.8ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.4ms
# Speed: 3.1ms preprocess, 8.4ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 16.9ms
# Speed: 3.8ms preprocess, 16.9ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 21.6ms
# Speed: 5.3ms preprocess, 21.6ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 25.0ms
# Speed: 4.3ms preprocess, 25.0ms inference, 2.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 0.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.7ms
# Speed: 3.9ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.4ms
# Speed: 3.6ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 12.4ms
# Speed: 4.1ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 14.7ms
# Speed: 7.0ms preprocess, 14.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.6ms
# Speed: 3.5ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 9.2ms
# Speed: 3.3ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 8.5ms
# Speed: 3.2ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 (no detections), 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.9ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 1 car, 29.7ms
# Speed: 4.1ms preprocess, 29.7ms inference, 4.2ms postprocess per image at shape (1, 3, 352, 640)
