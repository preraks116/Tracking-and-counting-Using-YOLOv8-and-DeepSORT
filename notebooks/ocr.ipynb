# %% [markdown]
# I had to install tesseract on my machine to make this work
# ```python
# sudo pacman -S tesseract tesseract-data-eng
# ```

# %%
import cv2
import numpy as np
import pytesseract
import queue
import threading
import time
from PIL import Image
import io
import re

# %%
INPUT_VIDEO_PATH = "data/videos/Rec16-1.mp4"
OUTPUT_VIDEO_PATH = "output/Rec16-1_trimmed.mp4"
OUTPUT_TXT_PATH = "output/timestamps/Rec16-1_trimmed.txt"

# %%
timestamp_region = (100, 831, 193, 865)  # (x1, y1, x2, y2)

# %%
def read_frames(video_path, frame_queue, stop_event):
    cap = cv2.VideoCapture(video_path)
    while not stop_event.is_set():
        ret, frame = cap.read()
        if not ret:
            break
        frame_queue.put(frame)
    cap.release()
    frame_queue.put(None)  # Sentinel to signal end of video

# %%
def process_frames(frame_queue, output_queue, timestamp_queue, timestamp_region, stop_event):
    prev_timestamp = None
    while not stop_event.is_set():
        frame = frame_queue.get()
        if frame is None:
            break
        
        x1, y1, x2, y2 = timestamp_region
        timestamp_img = frame[y1:y2, x1:x2]
        
        gray = cv2.cvtColor(timestamp_img, cv2.COLOR_BGR2GRAY)
        thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
        
        timestamp = pytesseract.image_to_string(thresh, config='--psm 7').strip()
        
        if timestamp != prev_timestamp:
            output_queue.put((timestamp, frame))
            # Remove colons and keep only numbers
            cleaned_timestamp = re.sub(r'[^\d]', '', timestamp)
            print(f'Processed frame with timestamp: {cleaned_timestamp}')
            timestamp_queue.put(cleaned_timestamp)
            prev_timestamp = timestamp
        
        frame_queue.task_done()
    
    output_queue.put(None)  # Sentinel to signal end of processing
    timestamp_queue.put(None)  # Sentinel for timestamp queue

# %%
def write_video(output_queue, output_path, frame_size, fps, stop_event):
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, frame_size)
    frame_count = 0
    
    while not stop_event.is_set():
        item = output_queue.get()
        if item is None:
            break
        
        timestamp, frame = item
        out.write(frame)
        frame_count += 1
        
        if frame_count % 100 == 0:
            print(f"Processed {frame_count} unique frames")
        
        output_queue.task_done()
    
    out.release()
    print(f"Video processing complete. {frame_count} unique frames extracted.")

# %%
def write_timestamps(timestamp_queue, output_path, stop_event):
    with open(output_path, 'w') as f:
        while not stop_event.is_set():
            timestamp = timestamp_queue.get()
            if timestamp is None:
                break
            f.write(f"{timestamp}\n")
            timestamp_queue.task_done()
    print(f"Timestamp file created: {output_path}")

# %%
def extract_unique_timestamp_frames_to_video(input_video_path, output_video_path, output_timestamp_path, timestamp_region):
    cap = cv2.VideoCapture(input_video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    cap.release()

    frame_queue = queue.Queue(maxsize=100)
    output_queue = queue.Queue(maxsize=100)
    timestamp_queue = queue.Queue()
    stop_event = threading.Event()

    read_thread = threading.Thread(target=read_frames, args=(input_video_path, frame_queue, stop_event))
    process_thread = threading.Thread(target=process_frames, args=(frame_queue, output_queue, timestamp_queue, timestamp_region, stop_event))
    write_video_thread = threading.Thread(target=write_video, args=(output_queue, output_video_path, frame_size, fps, stop_event))
    write_timestamp_thread = threading.Thread(target=write_timestamps, args=(timestamp_queue, output_timestamp_path, stop_event))

    read_thread.start()
    process_thread.start()
    write_video_thread.start()
    write_timestamp_thread.start()

    try:
        read_thread.join()
        process_thread.join()
        write_video_thread.join()
        write_timestamp_thread.join()
    except KeyboardInterrupt:
        print("Stopping processing...")
        stop_event.set()
        read_thread.join()
        process_thread.join()
        write_video_thread.join()
        write_timestamp_thread.join()

    return output_video_path, output_timestamp_path

# %%
# for finding the timestamp region
def display_timestamp_region(video_path, timestamp_region):
    """
    Get the first frame of a video, draw a box around the timestamp region,
    and display the frame.

    :param video_path: Path to the input video file
    :param timestamp_region: Tuple of (x1, y1, x2, y2) specifying the region for timestamp
    """
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Read the first frame
    ret, frame = cap.read()
    if not ret:
        print("Failed to read the video file.")
        return

    # Release the video capture object
    cap.release()

    # Draw a rectangle around the timestamp region
    x1, y1, x2, y2 = timestamp_region
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

    # Add text to indicate the timestamp region
    cv2.putText(frame, "Timestamp Region", (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow("First Frame with Timestamp Region", frame)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    # Save the frame as an image file
    cv2.imwrite("first_frame_with_timestamp.jpg", frame)
    print("Frame saved as 'first_frame_with_timestamp.jpg'")

# display_timestamp_region(INPUT_VIDEO_PATH, timestamp_region)

# %%
# result_video = extract_unique_timestamp_frames_to_video(INPUT_VIDEO_PATH, OUTPUT_VIDEO_PATH, OUTPUT_TXT_PATH, timestamp_region)
# print(f"Output video saved to: {result_video}")

# %%
import os
def process_video(video_config):
    input_video_path = video_config['input_path']
    video_id = os.path.splitext(os.path.basename(input_video_path))[0]
    output_dir = 'output'
    os.makedirs(output_dir, exist_ok=True)
    output_video_path = os.path.join(output_dir, f"{video_id}_trimmed.mp4")
    output_txt_path = os.path.join(output_dir, 'timestamps', f"{video_id}_trimmed.txt")
    os.makedirs(os.path.dirname(output_txt_path), exist_ok=True)
    timestamp_region = video_config['timestamp_region']
    
    extract_unique_timestamp_frames_to_video(input_video_path, output_video_path, output_txt_path, timestamp_region)

# %%
import concurrent.futures

def process_videos(video_configs):
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(process_video, config) for config in video_configs]
        
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()
            except Exception as e:
                print(f"An error occurred: {str(e)}")

# %%
video_configs = [
    {
        'input_path': 'data/videos/Rec16-1.mp4',
        'timestamp_region': (100, 831, 193, 865)
    }
]

# %%
process_videos(video_configs)
# Out:
# Processed frame with timestamp: 000000120
# Processed frame with timestamp: 000000140
# Processed frame with timestamp: 000000160
# Processed frame with timestamp: 000000200
# Processed frame with timestamp: 000000280
# Processed frame with timestamp: 000000320
# Processed frame with timestamp: 000000400
# Processed frame with timestamp: 000000460
# Processed frame with timestamp: 000000480
# Processed frame with timestamp: 000000500
# Processed frame with timestamp: 000000520
# Processed frame with timestamp: 000000540
# Processed frame with timestamp: 000000560
# Processed frame with timestamp: 000000580
# Processed frame with timestamp: 000000600
# Processed frame with timestamp: 000000620
# Processed frame with timestamp: 000000639
# Processed frame with timestamp: 000000679
# Processed frame with timestamp: 000000699
# Processed frame with timestamp: 000000719
# Processed frame with timestamp: 000000759
# Processed frame with timestamp: 000000779
# Processed frame with timestamp: 000000799
# Processed frame with timestamp: 0000008719
# Processed frame with timestamp: 000000839
# Processed frame with timestamp: 000000859
# Processed frame with timestamp: 000000879
# Processed frame with timestamp: 000000899
# Processed frame with timestamp: 000000919
# Processed frame with timestamp: 000000939
# Processed frame with timestamp: 000000959
# Processed frame with timestamp: 000000979
# Processed frame with timestamp: 000000999
# Processed frame with timestamp: 000001019
# Processed frame with timestamp: 000001039
# Processed frame with timestamp: 000001059
# Processed frame with timestamp: 000001079
# Processed frame with timestamp: 000001099
# Processed frame with timestamp: 000001119
# Processed frame with timestamp: 000001139
# Processed frame with timestamp: 000001159
# Processed frame with timestamp: 000001179
# Processed frame with timestamp: 000001199
# Processed frame with timestamp: 000001219
# Processed frame with timestamp: 000001239
# Processed frame with timestamp: 000001259
# Processed frame with timestamp: 000001279
# Processed frame with timestamp: 000001299
# Processed frame with timestamp: 000001319
# Processed frame with timestamp: 000001339
# Processed frame with timestamp: 000001359
# Processed frame with timestamp: 000001379
# Processed frame with timestamp: 000001399
# Processed frame with timestamp: 000001419
# Processed frame with timestamp: 000001439
# Processed frame with timestamp: 00001459
# Processed frame with timestamp: 00001479
# Processed frame with timestamp: 00001499
# Processed frame with timestamp: 000001499
# Processed frame with timestamp: 000001519
# Processed frame with timestamp: 000001539
# Processed frame with timestamp: 000001559
# Processed frame with timestamp: 000001579
# Processed frame with timestamp: 000001599
# Processed frame with timestamp: 000001619
# Processed frame with timestamp: 000001639
# Processed frame with timestamp: 000001659
# Processed frame with timestamp: 000001679
# Processed frame with timestamp: 000001699
# Processed frame with timestamp: 000001719
# Processed frame with timestamp: 000001739
# Processed frame with timestamp: 000001759
# Processed frame with timestamp: 000001779
# Processed frame with timestamp: 000001799
# Processed frame with timestamp: 000001819
# Processed frame with timestamp: 000001839
# Processed frame with timestamp: 000001859
# Processed frame with timestamp: 000001879
# Processed frame with timestamp: 000001899
# Processed frame with timestamp: 000001919
# Processed frame with timestamp: 000001939
# Processed frame with timestamp: 000001959
# Processed frame with timestamp: 000001979
# Processed frame with timestamp: 000001999
# Processed frame with timestamp: 000002019
# Processed frame with timestamp: 000002639
# Processed frame with timestamp: 000002039
# Processed frame with timestamp: 000002059
# Processed frame with timestamp: 000002079
# Processed frame with timestamp: 000002099
# Processed frame with timestamp: 000002119
# Processed frame with timestamp: 000002139
# Processed frame with timestamp: 000002159
# Processed frame with timestamp: 000002179
# Processed frame with timestamp: 000002199
# Processed frame with timestamp: 000002219
# Processed frame with timestamp: 000002239
# Processed frame with timestamp: 000002259
# Processed frame with timestamp: 000002279
# Processed frame with timestamp: 000002299
# Processed 100 unique frames
# Processed frame with timestamp: 000002319
# Processed frame with timestamp: 000002339
# Processed frame with timestamp: 000002359
# Processed frame with timestamp: 000002378
# Processed frame with timestamp: 000002398
# Processed frame with timestamp: 0000024718
# Processed frame with timestamp: 000002438
# Processed frame with timestamp: 000002458
# Processed frame with timestamp: 00002478
# Processed frame with timestamp: 000002498
# Processed frame with timestamp: 000002518
# Processed frame with timestamp: 000002538
# Processed frame with timestamp: 000002558
# Processed frame with timestamp: 000002578
# Processed frame with timestamp: 000002598
# Processed frame with timestamp: 000002618
# Processed frame with timestamp: 000002638
# Processed frame with timestamp: 000002658
# Processed frame with timestamp: 000002678
# Processed frame with timestamp: 000002698
# Processed frame with timestamp: 000002718
# Processed frame with timestamp: 000002738
# Processed frame with timestamp: 000002758
# Processed frame with timestamp: 000002778
# Processed frame with timestamp: 000002798
# Processed frame with timestamp: 000002818
# Processed frame with timestamp: 000002838
# Processed frame with timestamp: 000002858
# Processed frame with timestamp: 000002878
# Processed frame with timestamp: 000002898
# Processed frame with timestamp: 000002918
# Processed frame with timestamp: 000002938
# Processed frame with timestamp: 000002958
# Processed frame with timestamp: 000002978
# Processed frame with timestamp: 000002998
# Processed frame with timestamp: 000003018
# Processed frame with timestamp: 000003038
# Processed frame with timestamp: 000003058
# Processed frame with timestamp: 000003078
# Processed frame with timestamp: 000003098
# Processed frame with timestamp: 000003118
# Processed frame with timestamp: 000003138
# Processed frame with timestamp: 000003158
# Processed frame with timestamp: 000003178
# Processed frame with timestamp: 000003198
# Processed frame with timestamp: 000003218
# Processed frame with timestamp: 000003238
# Processed frame with timestamp: 000003258
# Processed frame with timestamp: 000003278
# Processed frame with timestamp: 000003293
# Processed frame with timestamp: 000003318
# Processed frame with timestamp: 000003338
# Processed frame with timestamp: 000003358
# Processed frame with timestamp: 000003378
# Processed frame with timestamp: 000003398
# Processed frame with timestamp: 000003418
# Processed frame with timestamp: 000003438
# Processed frame with timestamp: 000003458
# Processed frame with timestamp: 00003478
# Processed frame with timestamp: 000003498
# Processed frame with timestamp: 000003518
# Processed frame with timestamp: 000003538
# Processed frame with timestamp: 000003558
# Processed frame with timestamp: 000003578
# Processed frame with timestamp: 000003598
# Processed frame with timestamp: 000003618
# Processed frame with timestamp: 000003638
# Processed frame with timestamp: 000003658
# Processed frame with timestamp: 000003678
# Processed frame with timestamp: 000003698
# Processed frame with timestamp: 000003798
# Processed frame with timestamp: 000003818
# Processed frame with timestamp: 000003838
# Processed frame with timestamp: 000003858
# Processed frame with timestamp: 000003878
# Processed frame with timestamp: 000003938
# Processed frame with timestamp: 000003958
# Processed frame with timestamp: 000003978
# Processed frame with timestamp: 000003993
# Processed frame with timestamp: 000004018
# Processed frame with timestamp: 000004038
# Processed frame with timestamp: 000004058
# Processed frame with timestamp: 000004078
# Processed frame with timestamp: 000004097
# Processed frame with timestamp: 000004117
# Processed frame with timestamp: 000004137
# Processed frame with timestamp: 000004177
# Processed frame with timestamp: 000004277
# Processed frame with timestamp: 000004297
# Processed frame with timestamp: 000004497
# Processed frame with timestamp: 000004517
# Processed frame with timestamp: 000004537
# Processed frame with timestamp: 000004557
# Processed frame with timestamp: 000004577
# Processed frame with timestamp: 000004597
# Processed frame with timestamp: 000004617
# Processed frame with timestamp: 000004637
# Processed frame with timestamp: 000004657
# Processed frame with timestamp: 000004677
# Processed frame with timestamp: 000004697
# Processed 200 unique frames
# Processed frame with timestamp: 000004717
# Processed frame with timestamp: 000004737
# Processed frame with timestamp: 000004757
# Processed frame with timestamp: 000004777
# Processed frame with timestamp: 000004797
# Processed frame with timestamp: 000004817
# Processed frame with timestamp: 000004837
# Processed frame with timestamp: 000004857
# Processed frame with timestamp: 000004877
# Processed frame with timestamp: 000004897
# Processed frame with timestamp: 000004917
# Processed frame with timestamp: 000004937
# Processed frame with timestamp: 000004957
# Processed frame with timestamp: 000004977
# Processed frame with timestamp: 000004997
# Processed frame with timestamp: 000005017
# Processed frame with timestamp: 000005037
# Processed frame with timestamp: 000005057
# Processed frame with timestamp: 000005077
# Processed frame with timestamp: 000005097
# Processed frame with timestamp: 000005117
# Processed frame with timestamp: 000005197
# Processed frame with timestamp: 000005237
# Processed frame with timestamp: 000005257
# Processed frame with timestamp: 000005277
# Processed frame with timestamp: 000005297
# Processed frame with timestamp: 000005317
# Processed frame with timestamp: 000005337
# Processed frame with timestamp: 000005357
# Processed frame with timestamp: 000005377
# Processed frame with timestamp: 000005397
# Processed frame with timestamp: 000005417
# Processed frame with timestamp: 000005437
# Processed frame with timestamp: 000005457
# Processed frame with timestamp: 000005477
# Processed frame with timestamp: 00005477
# Processed frame with timestamp: 000005477
# Processed frame with timestamp: 000005497
# Processed frame with timestamp: 000005517
# Processed frame with timestamp: 000005537
# Processed frame with timestamp: 000005557
# Processed frame with timestamp: 000005577
# Processed frame with timestamp: 000005597
# Processed frame with timestamp: 000005617
# Processed frame with timestamp: 000005637
# Processed frame with timestamp: 000005657
# Processed frame with timestamp: 000005677
# Processed frame with timestamp: 000005697
# Processed frame with timestamp: 000005717
# Processed frame with timestamp: 000005737
# Processed frame with timestamp: 000005817
# Processed frame with timestamp: 000005836
# Processed frame with timestamp: 000005876
# Processed frame with timestamp: 000005936
# Processed frame with timestamp: 000005956
# Processed frame with timestamp: 00005976
# Processed frame with timestamp: 000005996
# Processed frame with timestamp: 000006016
# Processed frame with timestamp: 000006036
# Processed frame with timestamp: 000006056
# Processed frame with timestamp: 000006076
# Processed frame with timestamp: 000006096
# Processed frame with timestamp: 000006116
# Processed frame with timestamp: 000006136
# Processed frame with timestamp: 000006156
# Processed frame with timestamp: 000006176
# Processed frame with timestamp: 000006196
# Processed frame with timestamp: 000006216
# Processed frame with timestamp: 000006236
# Processed frame with timestamp: 000006256
# Processed frame with timestamp: 000006276
# Processed frame with timestamp: 000006296
# Processed frame with timestamp: 000006316
# Processed frame with timestamp: 000006336
# Processed frame with timestamp: 000006456
# Processed frame with timestamp: 00006476
# Processed frame with timestamp: 000006496
